# %%
import polars as pl

# %%
df = pl.read_parquet('s3://zirk-finance-tracker/transaction/current/*')

# %%
df
# Out:
# shape: (672, 41)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ account_i ┆ transacti ┆ authorize ┆ category ┆ … ┆ split_ori ┆ transacti ┆ transacti ┆ transacti │
# │ d         ┆ on_amount ┆ d_datetim ┆ ---      ┆   ┆ gin_id    ┆ on_year   ┆ on_month  ┆ on_day    │
# │ ---       ┆ ---       ┆ e         ┆ null     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ str       ┆ f64       ┆ ---       ┆          ┆   ┆ null      ┆ i64       ┆ i64       ┆ i64       │
# │           ┆           ┆ null      ┆          ┆   ┆           ┆           ┆           ┆           │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ mvK5EEePJ ┆ 15.54     ┆ null      ┆ null     ┆ … ┆ null      ┆ 2025      ┆ 11        ┆ 26        │
# │ AtZKeYOnr ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆           │
# ...
